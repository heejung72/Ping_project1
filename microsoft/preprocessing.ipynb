# %% [markdown]
# # 다시 돌리면 결과가 달라지거나 오류가 날 수 있으니 실행시키지 말아주세요.

# %%
import os
import glob

##.asm이 아닌 파일 삭제
def delete_files_except_asm(directory):
    files = glob.glob(os.path.join(directory, "*"))

    for file in files:
        if not file.endswith(".asm"):
            os.remove(file)
            print(f"Deleted {file}.")

directory_path = "/content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train"

delete_files_except_asm(directory_path)
# Out:
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/h0IeuHBPEixRnNKVyOYq.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/FRxXsQuBCKOgewT38iz5.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/1YhJFKP0mIC5e6kD7iqS.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/39YX8jkenM2UHOvCRDq5.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/Eg0QLdf5AyMFwxo1K37H.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/4jpx7Ahlw9f31YMikoCv.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/KDW8jkt3SfAENRxPvlpa.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/5QnvTRCteUqcpaL3J7SW.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/d7czUVqJApx6WEj4ownT.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/FRzN6ZiS5KU3Iyql2sc7.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/3aAduIoFRi8fj6Q54xNz.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/eG3621nPryiCxTS8LhUw.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/6WuXimIJaPd3x8QoGUH0.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/BaZ7fikmQxcVzTSlUs4q.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/d7aHABNQz41Sni2XyVUJ.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/CkzJnxomRNpMBfeK8TDg.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/9mHqfWkgcJb7utKZ5rCV.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/bx3MXBwc0zulDOa1UqN4.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/1YIJUZv2wtS63gf9es8p.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/5QkxLnYPlrhFpwDCZ67W.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/8btcXEfH4v9ITwU7OSsg.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/cL0AkjRPF3NndlTDxe1g.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/4JrEyAeIS67UPfkYVz52.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/gGPBDhr24EI875LfTNXV.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/bAZhqgSnCfNdXPDptGyi.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/9ml614yxaYqeibfruLWz.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/gGrBPR4c8KkNWHuA61UY.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/hQnAcOfHYisDkINaod7L.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/9mKvw8t3d6jRVfnzsDIJ.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/F1nhXPej7m8KOUtGTVRk.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/DsAdQFkSxr74MywUfiGc.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/BAyEjNmU0FSDwTZiWf4X.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/ieUqYbvXQJhLB4NDm097.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/H0evJ1QxsltOCmkDaTGr.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/gGv9msCKZNuaArhTkl0j.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/AK0WapSl9V5GYu1HsxLB.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/cl0W7xzTAYj9CEXJkS8Z.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/1yIvRAMqz0K6xXPBZfQ8.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/BxcUOqI5b8zn2mlrXSt9.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/cl0e6QDGkbwLVuSZrHxo.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/kDyOh6d8WQNTEoxJYUg1.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/aK4CPDZf05uQiwn7Or6V.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/iYfVGj6l2JWSXdyM538K.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/iygdLJ12UmnPhGqtsSCo.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/dsB2UgC4XFQ1cj8DMyhT.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/4jVLlkxAIGvb3MBzDYHc.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/4jPxiYkftVRhZEpgrLI2.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/f1KTZSymHw5na9Vz4Nsd.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/4JlgupTC2XdIvxE1oHjq.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/JnHGRI2v5NuB9lpsEOCS.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/H0CJMeXs7oU4Z3h9RqYz.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/HqFd1seJ8IURTuwDbW90.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/5qh0jnJ9X3N4rimob6Wg.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/d6D27zlaQs4EWPKkVHvB.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/IYACa9WBVQESgJTDtfXh.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/EFyS8WGvdetUPbqiBhID.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/8bIuJwoxYKjFVWSdnHi6.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/KdPahj5FQB4RCbNEzsnS.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/5qEodvVi3umUTpZfskhP.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/IY9HnrhqPomv3L6bAzeX.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/FRTmvrEKAXNotPaWdqn4.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/D6C4HPXEmQVd7Y9esqv0.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/Ggm5d6VvPXjsCAKzI8B4.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/BX1krdbNEPmgFeCaRy52.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/KDMqVc9yIEfmB2A7slz1.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/
bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/F0sNpT8XAKJg4BvwxZPS.bytes.
# Deleted /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train/8bfAcO634YBuCm5ND1gx.bytes.

# %%
import pandas as pd

csv_file_path = "/content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/trainLabels.csv"
train_label = pd.read_csv(csv_file_path)
print(train_label)
# Out:
#                          Id  Class
# 0      01kcPWA9K2BOxQeS5Rju      1
# 1      04EjIdbPV5e1XroFOpiN      1
# 2      05EeG39MTRrI6VY21DPd      1
# 3      05rJTUWYAKNegBk2wE8X      1
# 4      0AnoOZDNbPXIr2MRBSCJ      1
# ...                     ...    ...
# 10863  KFrZ0Lop1WDGwUtkusCi      9
# 10864  kg24YRJTB8DNdKMXpwOH      9
# 10865  kG29BLiFYPgWtpb350sO      9
# 10866  kGITL4OJxYMWEQ1bKBiP      9
# 10867  KGorN9J6XAC4bOEkmyup      9
#
# [10868 rows x 2 columns]

# %% [markdown]
# 파일 개수 10868개, train_label의 길이 10868.
# 모두 정상적으로 압축해제된듯함.

# %%
train_label["Class"].value_counts()
# Out:
# Class
# 3    2942
# 2    2478
# 1    1541
# 8    1228
# 9    1013
# 6     751
# 4     475
# 7     398
# 5      42
# Name: count, dtype: int64

# %%
import shutil

# 분류가 5번인 파일들의 파일 이름
files_to_move = (train_label[train_label['Class'] == 5]['Id']+'.asm').tolist()

# 파일을 옮길 폴더
destination_folder_path = "/content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5"

# 파일 옮기기
source_folder_path = "/content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train"  # 파일들이 위치한 폴더 경로
for file_name in files_to_move:
    source_file_path = os.path.join(source_folder_path, file_name)
    destination_file_path = os.path.join(destination_folder_path, file_name)

    if os.path.exists(source_file_path):
        shutil.move(source_file_path, destination_file_path)
        print(f"{file_name}를 {destination_folder_path}로 옮겼습니다.")
    else:
        print(f"{source_file_path}가 존재하지 않습니다.")
# Out:
# 0qjuDC7Rhx9rHkLlItAp.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# 1IpWLz6eyhVxDAfQMKEd.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# 1KB3Z7gd5aN4Xmx8W0sf.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# 2aHfrLhcPTj5GnFZXUCN.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# 2pwjzv6eGEb8QmHPfxSc.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# 2qAtoGOuMQZdmH3y7bEY.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# 3m8kb5ILPrHcMC1o9Nht.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# 3zZpqyclD9B2v5Qas18m.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# 40KRbGeQZ8PwcUgt5joa.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# 4UTMdcZkxzLvwygO8EuK.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# 5tMCNKDogQ2x7zwUbpcZ.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# 7cyYPthi5KmvXEs2NkRj.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# 8wm2jYBqV30okUMfuDCd.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# AeCXyFRcU2SsgvVTpMzi.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# asKPnzUXjShMc0Tl6Wge.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# b59dlNEacoYUAyeR4Ipq.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# B6dzEY3kKIn8me9McfGg.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# bGPHZFpAL3N957064wzj.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# BKXtxeYlLsprabEWIQhn.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# cIojVJGQOtrL0S1ApeDY.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# CRrAOvzk452LVZIGMWsq.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# cYb4XuNSqOA9IFLHseG1.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# DEyOUKzN2g8suv96eYoC.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# Dj3FqX9IAHco2tG1UOZS.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# dKcE7Q1zuFViSaDRUtxY.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# e2r6IncxE1LQOKFGgphj.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# EB0d2fJGLHam1tQCUDWu.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# ei0C84XpoqcAS6v5ZExI.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# epLciPaHrTu1gl4CW7Uf.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# F6nOrb9ipd0SskWuJjUw.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# FdiEeV3N8WtUSXjmcrxo.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# Fnda3PuqJT6Ep5vjOWCk.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# FsirpP0oDwXeAzC2KndG.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# fyH8oWql4rg7tEJSLpIB.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# gB105vrJPbcGCtuj7p4a.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# GbTUXFYkMoafQSe1zN94.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# GkMBlvTidr5oyYOVJCwc.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# Hc5LqZVK2yzlsb8BEfdO.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# hrguW0CqMt2mJdfvX8IB.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# hZiVAw5nREjHU1qodatK.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# i8WIr0dtVHSGMmwFlcUY.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.
# idjesBrKybwkzPXMalUL.asm를 /content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5로 옮겼습니다.

# %%
#class.value_counts()
print(len(train_label), train_label["Class"].value_counts())
# Out:
# 10868 Class
# 3    2942
# 2    2478
# 1    1541
# 8    1228
# 9    1013
# 6     751
# 4     475
# 7     398
# 5      42
# Name: count, dtype: int64

# %%
def count_files_in_directory(directory):
    files = os.listdir(directory)

    return len(files)

directory_path = "/content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train"

file_count = count_files_in_directory(directory_path)
print(f"train 폴더 내 파일 개수: {file_count}")
# Out:
# train 폴더 내 파일 개수: 10826

# %% [markdown]
# 10868-42(class_5)=10826

# %%
directory_path = "/content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/class_5"

file_count = count_files_in_directory(directory_path)
print(f"class_5 폴더 내 파일 개수: {file_count}")
# Out:
# class_5 폴더 내 파일 개수: 42

# %% [markdown]
# class5에 해당하는 파일들 정상적으로 옮겨짐.

# %%
import random

# class 5가 아닌 행 선택
selected_rows = train_label[train_label.iloc[:, 1] != 5]

# 각 500개씩 랜덤하게 추출
random_samples = selected_rows.groupby(selected_rows.iloc[:, 1]).apply(lambda x: x.sample(n=200))

# 새로운 데이터프레임 생성
new_train_label = random_samples.reset_index(drop=True)

print(new_train_label['Class'].value_counts())
# Out:
# Class
# 1    200
# 2    200
# 3    200
# 4    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64

# %%
files_to_move = (new_train_label['Id']+'.asm').tolist()

# 파일을 옮길 폴더 경로 설정
destination_folder_path = "/content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/raw_asm_data"

# 파일 옮기기
source_folder_path = "/content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/train_data/train"  # 파일들이 위치한 폴더 경로
i=0
for file_name in files_to_move:
    source_file_path = os.path.join(source_folder_path, file_name)
    destination_file_path = os.path.join(destination_folder_path, file_name)

    if os.path.exists(source_file_path):
        shutil.move(source_file_path, destination_file_path)
        #print(f"{file_name}를 {destination_folder_path}로 옮겼습니다.")
        i+=1

print(i,'개 옮겼습니다.')
# Out:
# 1600 개 옮겼습니다.

# %%
directory_path = "/content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/raw_asm_data"

file_count = count_files_in_directory(directory_path)
print(f"raw_asm_data 폴더 내 파일 개수: {file_count}")
# Out:
# raw_asm_data 폴더 내 파일 개수: 1600

# %%
# 새로운 데이터프레임을 CSV 파일로 저장
new_csv_file_path = "/content/drive/MyDrive/Ping!_AI악성코드분류기/microsoft/raw_asm_data/train_label_200.csv"
new_train_label.to_csv(new_csv_file_path, index=False)

# %%
file_count = count_files_in_directory(directory_path)
print(f"raw_asm_data 폴더 내 파일 개수: {file_count}")
# Out:
# raw_asm_data 폴더 내 파일 개수: 1601

# %% [markdown]
# **# 결론**
#
# 모델링에 필요한 데이터
# - 8개 class의 각 200개 .asm파일 (1600개)
# - 해당 1600개 파일의 label .csv파일 (1개)
#
# 은 raw_asm_data폴더(1601개)에 저장되어 있음.
#
# //
#
# 라벨링은 이후 모델링 과정에서 해야할듯
